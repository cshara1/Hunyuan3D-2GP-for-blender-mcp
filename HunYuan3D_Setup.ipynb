# %% [markdown]
# # Hunyuan3D Server Setup
#
# This notebook helps you set up and run the external server required for the Blender MCP Addon.
# It supports Hunyuan3D-2GP (Local API).

# %%
# !git clone https://github.com/cshara1/Hunyuan3D-2GP-for-blender-mcp.git Hunyuan3D-2GP
# %cd Hunyuan3D-2GP/
# !pip install --upgrade pip setuptools wheel
# !python setup.py install

# %%
# Install dependencies (excluding Hunyuan3D-2GP)
# !pip install -r requirements.txt

# %%
# !pip install bitsandbytes --upgrade --force-reinstall
# !pip install diso --no-build-isolation
# !pip install --upgrade "numpy<2"

# %%
# 1. Install custom_rasterizer
# %cd hy3dgen/texgen/custom_rasterizer
# !python setup.py install
# 2. Install differentiable_renderer
# %cd ../differentiable_renderer
# !python setup.py install
# %cd ../../../

# %%
# Run the server
# The server will start on port 8081 by default.
print("Starting server...")
# !python api_server.py --share --auth-user user --auth-pass pass --enable_t23d --enable_tex --profile 4
